# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2
from scipy.signal import convolve2d
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
import seaborn as sns

# %%
pc=cv2.imread("c.jpeg",cv2.IMREAD_UNCHANGED)
plt.imshow(pc)

# %%
pc_clue=cv2.imread("c_clue.jpeg",cv2.IMREAD_UNCHANGED)
plt.imshow(pc_clue)

# %%
np.shape(pc_clue)
# Out:
# (64, 64, 3)

# %%
np.shape(pc)
# Out:
# (1680, 2600, 3)

# %%
imagen_copia= cv2.cvtColor(pc,cv2.COLOR_BGR2GRAY)
print(imagen_copia.shape)
plt.imshow(imagen_copia,cmap='gray')
# Out:
# (1680, 2600)

# %%
imagen_copiaclue= cv2.cvtColor(pc_clue,cv2.COLOR_BGR2GRAY)
print(imagen_copiaclue.shape)
plt.imshow(imagen_copiaclue,cmap='gray')
# Out:
# (64, 64)

# %% [markdown]
# # Redimensión de las imágenes
# Como son de diferente tamaño, para que el producto matricial esté definido, debemos redimensionar las imágenes.

# %%
#Conocer tamaño y canales 
#De arriba sabemos que una es de (1680,2600) y la otra es de (64,64)
#Vamos a hacer una redimensión proporcional de la grande a la pequeña.
#r = 64 /1680
#r2 = 64/2600
#dim = (int(1680*r),int(2600*r2))
#redimp = cv2.resize(imagen_copia,dim)
#print(redimp.shape)
#plt.imshow(redimp,cmap='gray')

# %%
FFT_pc=np.fft.fftn(imagen_copia)
FFt_pc=np.fft.fftshift(FFT_pc)
fft_pc_log=np.log(FFt_pc)
plt.imshow(np.abs(fft_pc_log))
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#@title Texto de título predeterminado
FFT_pcclue=np.fft.fftn(imagen_copiaclue)
FFt_pcclue=np.fft.fftshift(FFT_pcclue)
fft_pcclue_log=np.log(FFt_pcclue)
plt.imshow(np.abs(fft_pcclue_log))
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
convol = convolve2d(FFt_pcclue,FFt_pc)

# %%
convol.shape

# %%
inv_uni2=np.fft.fftn(convol)
FFt_pcclue=np.fft.fftshift(FFT_pcclue)
plt.imshow(np.abs(inv_uni2),cmap='Greys')
FFt_pcclue.shape
plt.show
